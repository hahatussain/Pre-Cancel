# %% [markdown]
# # Introduction #
#
# Model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %%
from tensorflow import keras
from tensorflow.keras import layers

#defining model
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(rate=0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(rate=0.3),
    layers.Dense(1, activation='sigmoid'),
])

q_1.check()
# Out:
# Correct

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check
q_2.check()
# Out:
# Correct

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 5s 21ms/step - loss: 0.5410 - binary_accuracy: 0.7362 - val_loss: 0.4351 - val_binary_accuracy: 0.7896
# Epoch 2/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.4237 - binary_accuracy: 0.8036 - val_loss: 0.4041 - val_binary_accuracy: 0.8096
# Epoch 3/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.4072 - binary_accuracy: 0.8103 - val_loss: 0.3974 - val_binary_accuracy: 0.8156
# Epoch 4/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.4031 - binary_accuracy: 0.8129 - val_loss: 0.3925 - val_binary_accuracy: 0.8196
# Epoch 5/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3974 - binary_accuracy: 0.8153 - val_loss: 0.3909 - val_binary_accuracy: 0.8207
# Epoch 6/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3909 - binary_accuracy: 0.8175 - val_loss: 0.3871 - val_binary_accuracy: 0.8227
# Epoch 7/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3872 - binary_accuracy: 0.8203 - val_loss: 0.3859 - val_binary_accuracy: 0.8224
# Epoch 8/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3820 - binary_accuracy: 0.8230 - val_loss: 0.3841 - val_binary_accuracy: 0.8254
# Epoch 9/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3821 - binary_accuracy: 0.8226 - val_loss: 0.3798 - val_binary_accuracy: 0.8279
# Epoch 10/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3799 - binary_accuracy: 0.8221 - val_loss: 0.3798 - val_binary_accuracy: 0.8274
# Epoch 11/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3761 - binary_accuracy: 0.8264 - val_loss: 0.3750 - val_binary_accuracy: 0.8314
# Epoch 12/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3738 - binary_accuracy: 0.8281 - val_loss: 0.3748 - val_binary_accuracy: 0.8267
# Epoch 13/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3706 - binary_accuracy: 0.8287 - val_loss: 0.3722 - val_binary_accuracy: 0.8296
# Epoch 14/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3683 - binary_accuracy: 0.8292 - val_loss: 0.3715 - val_binary_accuracy: 0.8311
# Epoch 15/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3677 - binary_accuracy: 0.8302 - val_loss: 0.3704 - val_binary_accuracy: 0.8310
# Epoch 16/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3640 - binary_accuracy: 0.8307 - val_loss: 0.3695 - val_binary_accuracy: 0.8322
# Epoch 17/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3603 - binary_accuracy: 0.8341 - val_loss: 0.3686 - val_binary_accuracy: 0.8316
# Epoch 18/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3601 - binary_accuracy: 0.8323 - val_loss: 0.3664 - val_binary_accuracy: 0.8325
# Epoch 19/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3603 - binary_accuracy: 0.8331 - val_loss: 0.3642 - val_binary_accuracy: 0.8351
# Epoch 20/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3557 - binary_accuracy: 0.8347 - val_loss: 0.3644 - val_binary_accuracy: 0.8354
# Epoch 21/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3569 - binary_accuracy: 0.8336 - val_loss: 0.3631 - val_binary_accuracy: 0.8345
# Epoch 22/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3546 - binary_accuracy: 0.8363 - val_loss: 0.3632 - val_binary_accuracy: 0.8352
# Epoch 23/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3529 - binary_accuracy: 0.8363 - val_loss: 0.3609 - val_binary_accuracy: 0.8366
# Epoch 24/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3488 - binary_accuracy: 0.8387 - val_loss: 0.3602 - val_binary_accuracy: 0.8366
# Epoch 25/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3499 - binary_accuracy: 0.8388 - val_loss: 0.3593 - val_binary_accuracy: 0.8366
# Epoch 26/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3470 - binary_accuracy: 0.8390 - val_loss: 0.3607 - val_binary_accuracy: 0.8361
# Epoch 27/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3459 - binary_accuracy: 0.8411 - val_loss: 0.3602 - val_binary_accuracy: 0.8374
# Epoch 28/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3476 - binary_accuracy: 0.8384 - val_loss: 0.3598 - val_binary_accuracy: 0.8379
# Epoch 29/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3467 - binary_accuracy: 0.8379 - val_loss: 0.3592 - val_binary_accuracy: 0.8389
# Epoch 30/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3430 - binary_accuracy: 0.8405 - val_loss: 0.3580 - val_binary_accuracy: 0.8379
# Epoch 31/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3435 - binary_accuracy: 0.8415 - val_loss: 0.3574 - val_binary_accuracy: 0.8374
# Epoch 32/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3436 - binary_accuracy: 0.8393 - val_loss: 0.3572 - val_binary_accuracy: 0.8381
# Epoch 33/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3414 - binary_accuracy: 0.8428 - val_loss: 0.3569 - val_binary_accuracy: 0.8385
# Epoch 34/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3413 - binary_accuracy: 0.8424 - val_loss: 0.3578 - val_binary_accuracy: 0.8390
# Epoch 35/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3377 - binary_accuracy: 0.8442 - val_loss: 0.3559 - val_binary_accuracy: 0.8387
# Epoch 36/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3395 - binary_accuracy: 0.8436 - val_loss: 0.3575 - val_binary_accuracy: 0.8388
# Epoch 37/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3348 - binary_accuracy: 0.8454 - val_loss: 0.3560 - val_binary_accuracy: 0.8392
# Epoch 38/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3409 - binary_accuracy: 0.8415 - val_loss: 0.3581 - val_binary_accuracy: 0.8366
# <AxesSubplot:title={'center':'Accuracy'}>
